# %% [markdown]
# ## Import packages and set working directory

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats

# %% [markdown]
# ## Calculate differences by question type for all hires

# %%
# Create dictionary of dataframes split by Survey+Question
dfs = {i:data for i, data in df.groupby('Survey+Question')}

# Create empty list to hold aggregated data and empty dictionary to hold pre- and post-covid values by question
a1 = []
all_dict = {}

# Loop over dictionary of dataframes by Survey+Question
for key, data in dfs.items():
    # Split dataframe into pre- and post-covid groups
    pre_cnt = data[data['Covid Grp'] == 'Pre-Covid']['Value']
    pst_cnt = data[data['Covid Grp'] == 'Post-Covid']['Value']
    # Add pre- and post-covid values to empty dictionary for later
    all_dict[key] = {'Pre-Covid': pre_cnt, 'Post-Covid': pst_cnt}
    # Append metrics to empty list for each question
    a1.append({'Survey+Question': key,
               'Pre-Covid Respondents': len(pre_cnt),
               'Post-Covid Respondents': len(pst_cnt),
               'Pre-Covid Score': data[data['Covid Grp'] == 'Pre-Covid']['Value'].mean(),
               'Post-Covid Score': data[data['Covid Grp'] == 'Post-Covid']['Value'].mean(),
               'Difference (Post-Pre)': np.subtract(data[data['Covid Grp'] == 'Post-Covid']['Value'].mean(), data[data['Covid Grp'] == 'Pre-Covid']['Value'].mean())})

# Create empty list to hold p-values by Survey+Question
a2 = []

# Loop over dictionary created above with pre- and post-covid values by Survey+Question
for key, data in all_dict.items():
    # Perform a one-tailed Mann-Whitney U test on the pre- and post-covid data
    stat, pvalue = stats.mannwhitneyu(data['Pre-Covid'], data['Post-Covid'], alternative='greater')
    # Set the alpha level
    alpha = 0.05
    # Print the Surve+Question and the conclusion given by the p-value
    if pvalue > alpha:
        print(key, '\nSAME DISTRIBUTION (FAIL TO REJECT H0)\n')
    else:
        print(key, '\nDIFFERENT DISTRIBUTION (REJECT H0)\n')
    # Append the Survey+Question and p-value to the empty list created above
    a2.append({'Survey+Question': key,
               'PValue': pvalue})
    
# Convert dicts to dataframes and merge together
a1 = pd.DataFrame(a1)
a2 = pd.DataFrame(a2)
a = a1.merge(a2, on='Survey+Question')

# Sort the columns of the final dataframe
a = a[['Survey+Question', 'Pre-Covid Respondents', 'Post-Covid Respondents', 'Pre-Covid Score', 'Post-Covid Score', 'Difference (Post-Pre)', 'PValue']]
# Out:
# 14 Day EE: I am satisfied with the company's overall hiring process (application, interview, and on-boarding).
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day EE: I feel like joining LG&E and KU Energy was the right decision.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day EE: I have a clear understanding of the company's benefits.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day EE: I received a welcome call from the hiring manager.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day EE: I was given a clear understanding of the position and job expectations.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day EE: My co-workers have made me feel welcomed at LG&E and KU Energy.
# DIFFERENT DISTRIBUTION (REJECT H0)
#
# 14 Day EE: My workspace was ready when I arrived.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day EE: The Company's representative kept me well-informed at different points in the process.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day EE: The Company's representative was available to answer any questions.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day EE: The drug / alcohol screen process was clearly explained to me.
# DIFFERENT DISTRIBUTION (REJECT H0)
#
# 14 Day EE: The interviewers were able to answer my questions.
# DIFFERENT DISTRIBUTION (REJECT H0)
#
# 14 Day EE: The interviewers were prepared for the interviews.
# DIFFERENT DISTRIBUTION (REJECT H0)
#
# 14 Day EE: The interviews were well-organized.
# DIFFERENT DISTRIBUTION (REJECT H0)
#
# 14 Day EE: The job posting provided a clear explanation of the position.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day EE: The length of the online application was reasonable.
# DIFFERENT DISTRIBUTION (REJECT H0)
#
# 14 Day EE: The online application system was user friendly.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day EE: The person I report to has made me feel welcomed at LG&E and KU Energy.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day EE: The pre-employment assessment process was clearly explained to me.
# DIFFERENT DISTRIBUTION (REJECT H0)
#
# 14 Day EE: The steps in the recruiting process were clear to me.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day EE: The time between my application submission and the initial contact/communication I received from the company was 6 weeks or less.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day EE: There was a plan in place for my first few days on the job.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day Mgr: Brassring was user friendly.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day Mgr: Candidate applications / resumes were processed in a timely manner.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day Mgr: Candidates presented were qualified for the posted position.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day Mgr: I am satisfied with LG&E and KU’s recruiting and staffing process.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day Mgr: I am satisfied with the accuracy of the job description.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day Mgr: I am satisfied with the frequency of communication with the recruiter during the recruiting process.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day Mgr: Interview materials (guide and schedule) were free from error.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day Mgr: Interviews were well organized.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day Mgr: Key job competencies were effectively identified.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day Mgr: The candidates interviewed understood requirements of the position.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day Mgr: The interview guide questions were effective in the selection process.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day Mgr: The number of candidates presented was…
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day Mgr: The recruiter had a clear understanding of job requirements.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day Mgr: The recruiter provided quality insight / recommendations.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day Mgr: The recruiter provided solutions to recruitment needs / issues during the process.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day Mgr: The recruiter’s initial information gathering meeting was effective.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 14 Day Mgr: Time from requisition approval to candidate start date was reasonable.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 60 Day EE: How would you rate your satisfaction with the job itself.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 60 Day EE: I am proud to work for LG&E and KU Energy. & ...
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 60 Day EE: I can go to my immediate supervisor with questions and concerns.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 60 Day EE: I feel I am part of a team at work.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 60 Day EE: I feel I can reach my potential at LG&E and KU Energy.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 60 Day EE: I get a sense of purpose from my work.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 60 Day EE: I have a clear understanding of the company's benefits.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 60 Day EE: I have received the training I need to do a quality job.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 60 Day EE: I have the information I need to do my job.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 60 Day EE: I have the tools and technology that I need to be productive.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 60 Day EE: I have trust and confidence in my immediate supervisor.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 60 Day EE: I have work/life balance in my role.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 60 Day EE: I understand the performance my immediate supervisor expects from me at work.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 60 Day EE: I'm satisfied with the interaction with, and the support I receive from my team.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 60 Day EE: In my work environment, every precaution is taken to avoid accidents.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 60 Day EE: My immediate supervisor communicates effectively.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 60 Day EE: My immediate supervisor treats me with respect.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 60 Day EE: My new role has aligned with expectations set during the hiring process.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 60 Day EE: The stress related to the job is manageable.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 60 Day Mgr: I am satisfied with company resources that assist with onboarding new employees.
# DIFFERENT DISTRIBUTION (REJECT H0)
#
# 60 Day Mgr: Objectives and competencies have been established for the new employee. (PEP/EPR created)
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 60 Day Mgr: Overall, the employee hired has met or exceeded my expectations.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 60 Day Mgr: The new employee fits with our company’s culture.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 60 Day Mgr: The new employee has established positive working relationships with their co-workers.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 60 Day Mgr: The new employee has received the training needed to do a quality job.
# DIFFERENT DISTRIBUTION (REJECT H0)
#
# 60 Day Mgr: The new employee has received tools and technology to be productive.
# DIFFERENT DISTRIBUTION (REJECT H0)
#
# 60 Day Mgr: The new employee has the skills and experience necessary to be effective in their role.
# SAME DISTRIBUTION (FAIL TO REJECT H0)
#
# 60 Day Mgr: The new employee understands performance expectations.
# DIFFERENT DISTRIBUTION (REJECT H0)
